# %%
from emm.bin.symmetricize import Symmetricize
import matplotlib.pyplot as plt
import importlib

# %%
for i in range(100):
    shape = Symmetricize('../emm/matfiles/' + str(i+1) + '.mat')
    plt.figure(i)
    shape.do_everything("fit") #handles all the logic in symmetricizing fit curves
# Out:
# /opt/anaconda3/envs/emm/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for i in range(100):    
    shape = Symmetricize('../emm/matfiles/' + str(i+1) + '.mat')
    plt.figure(i)
    shape.do_everything("outerfit") #handles all the logic in symmetricizing outerfit curves
# Out:
# /opt/anaconda3/envs/emm/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
shape = Symmetricize('../emm/matfiles/1.mat')
print(shape.curve_area())
# Out:
# 12.656333739855022
