# %%
from emm.bin.symmetricize import Symmetricize
import matplotlib.pyplot as plt
import importlib

# %%
for i in range(10):
    shape = Symmetricize('../emm/matfiles/' + str(i+1) + '.mat')
    plt.figure(i)
    shape.do_everything("fit") #handles all the logic in symmetricizing fit curves

# %%
for i in range(10):    
    shape = Symmetricize('../emm/matfiles/' + str(i+1) + '.mat')
    plt.figure(i)
    shape.do_everything("outerfit") #handles all the logic in symmetricizing outerfit curves

# %%
shape = Symmetricize('../emm/matfiles/1.mat')
shape.curvature()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-426784c181a9> in <module>
#       1 shape = Symmetricize('../emm/matfiles/1.mat')
# ----> 2 shape.curvature()
#
# ~/EMM/emm/bin/symmetricize.py in curvature(self)
#     268             #adds up all the 1 / distance from center to point on protein coat
#     269             curv += 1 / math.sqrt((mid_x - self.x_outerfit_symmetric[i])**2 + (mid_y - self.y_outerfit_symmetric[i])**2)
# --> 270         curv /= len(self.x_outerfit_symmetric)
#     271         return curv
#     272
#
# NameError: name 'shape' is not defined
